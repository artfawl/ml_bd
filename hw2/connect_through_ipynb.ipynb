# %%
from pyhive import hive
import pandas as pd

# %%
con = hive.Connection(host='localhost', port=10000)

# %%
pd.read_sql('show tables', con)
# Out:
#             tab_name
# 0   hue__tmp_artists
# 1  parsed_tags_table
# 2              pokes
# 3           top_tags
# 4     top_tags_table

# %%
pd.read_sql('select * from hue__tmp_artists limit 5', con)
# Out:
#                   hue__tmp_artists.mbid hue__tmp_artists.artist_mb  \
# 0  cc197bad-dc9c-440d-a5b5-d52ba2e14234                   Coldplay
# 1  a74b1b7f-71a5-4011-9441-d0b5e4122711                  Radiohead
# 2  8bfac288-ccc5-448d-9573-c33ea2aa5c30      Red Hot Chili Peppers
# 3  73e5e69d-3554-40d8-8516-00cb38737a1c                    Rihanna
# 4  b95ce3ff-3d05-4e87-9e01-c97b66af13d4                     Eminem
#
#   hue__tmp_artists.artist_lastfm hue__tmp_artists.country_mb  \
# 0                       Coldplay              United Kingdom
# 1                      Radiohead              United Kingdom
# 2          Red Hot Chili Peppers               United States
# 3                        Rihanna               United States
# 4                         Eminem               United States
#
#   hue__tmp_artists.country_lastfm  \
# 0                  United Kingdom
# 1                  United Kingdom
# 2                   United States
# 3         Barbados; United States
# ...
